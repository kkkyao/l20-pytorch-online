# %%
import wandb

api = wandb.Api()

entity = "leyao-li-epfl-org"
project = "l2o-online(new1)"

runs = api.runs(f"{entity}/{project}")

print(f"Total runs: {len(runs)}")

for run in runs:
    print(run.name, run.id, run.state)
